# %% [markdown]
# # Load Data

# %%
import pandas as pd

path = 'DataMerge/A-RaceBias.csv'
RaceBias = pd.read_csv(path)
RaceBias
# Out:
#       GEOID  racial_bias  racial_explicit_bias  racial_weighted_bias  \
# 0        30     0.461000                   NaN                   NaN
# 1      1001     0.462460              1.160714              0.432357
# 2      1003     0.440297              1.260521              0.432839
# 3      1005     0.472971              0.976190              0.429265
# 4      1007     0.465729              0.791667              0.425924
# ...     ...          ...                   ...                   ...
# 3105  56037     0.357542              0.801724              0.351926
# 3106  56039     0.322408              0.588889              0.342007
# 3107  56041     0.265237              0.536585              0.346878
# 3108  56043     0.232684              1.750000              0.352061
# 3109  56045     0.398210              0.533333              0.356803
#
#       racial_weighted_explicit_bias
# 0                               NaN
# 1                          1.070972
# ...

# %%
import pandas as pd

path = 'DataMerge/B-SexBias.csv'
SexBias = pd.read_csv(path)
SexBias
# Out:
#       GEOID  sex_bias  sex_explicit_bias  sex_weighted_bias  \
# 0        30 -0.268537           0.000000                NaN
# 1      1001  0.347608           1.278571           0.397887
# 2      1003  0.424211           2.267974           0.443720
# 3      1005  0.474008           1.162162           0.445093
# 4      1007  0.381588           2.055556           0.421544
# ...     ...       ...                ...                ...
# 3064  56037  0.284804           1.151316           0.326077
# 3065  56039  0.211733           1.604478           0.296134
# 3066  56041  0.349592           0.972222           0.350689
# 3067  56043  0.104252           1.937500           0.331481
# 3068  56045  0.374224           1.909091           0.359069
#
#       sex_weighted_explicit_bias
# 0                            NaN
# 1                       1.461195
# 2                       2.185791
# 3                       1.509029
# 4                       2.029959
# ...                          ...
# ...

# %%
path = 'DataMerge/C-AgeDisparity.csv'
AgeDisparity = pd.read_csv(path)
AgeDisparity
# Out:
#       GEOID  Above75_WhiteRate  Above75_BlackRate  Above75_Disparity  \
# 0      1001           0.078813           0.041915           0.518869
# 1      1003           0.090385           0.042872           0.552145
# 2      1005           0.109362           0.053334           0.686496
# 3      1007           0.078180           0.037371           0.588648
# 4      1009           0.078214           0.049080           0.374917
# ...     ...                ...                ...                ...
# 3137  56037           0.045443           0.035117           0.227999
# 3138  56039           0.060040           0.005814           0.909457
# 3139  56041           0.051772           0.013158           0.750225
# 3140  56043           0.103430           0.045455           0.562396
# 3141  56045           0.095290           0.000000           1.007437
#
#       Above75_Whole  Above65_WhiteRate  Above65_BlackRate  Above65_Disparity  \
# ...

# %%
path = 'DataMerge/D-MeanIncome.csv'
MeanIncome = pd.read_csv(path)
MeanIncome
# Out:
#       GEOID  MeanInc_Total  MeanInc_White  MeanInc_Black  MeanInc_Disparity
# 0      1001        29819.0        33021.0        19610.0            13411.0
# 1      1003        32626.0        34639.0        18565.0            16074.0
# 2      1005        18473.0        25581.0        12369.0            13212.0
# 3      1007        20778.0        23509.0        10938.0            12571.0
# 4      1009        24747.0        25176.0        15911.0             9265.0
# ...     ...            ...            ...            ...                ...
# 3215  72145        11116.0        10927.0        13561.0            -2634.0
# 3216  72147        10426.0        11371.0        11626.0             -255.0
# 3217  72149        10894.0        11070.0        19955.0            -8885.0
# 3218  72151         9929.0        11199.0         9637.0             1562.0
# 3219  72153         8404.0         8313.0        11794.0            -3481.0
#
# [3220 rows x 5 columns]

# %%
path = 'DataMerge/E-MedianIncome.csv'
MedianIncome = pd.read_csv(path)
MedianIncome
# Out:
#       GEOID  MedianInc_Total  MedianInc_White  MedianInc_Black  \
# 0      1001          58731.0          66540.0          28808.0
# 1      1003          58320.0          61505.0          36616.0
# 2      1005          32525.0          46815.0          22357.0
# 3      1007          47542.0          52388.0          21964.0
# 4      1009          49358.0          49289.0          77518.0
# ...     ...              ...              ...              ...
# 3215  72145          19617.0          19638.0          21812.0
# 3216  72147          14936.0          14979.0          22882.0
# 3217  72149          19877.0          21279.0          32579.0
# 3218  72151          16295.0          18416.0          15588.0
# 3219  72153          14743.0          15936.0          14383.0
#
#       MedianInc_Disparity
# 0                 37732.0
# 1                 24889.0
# 2                 24458.0
# 3                 30424.0
# 4                -28229.0
# ...                   ...
# ...

# %%
path = 'DataMerge/F-PoliticalIdeology.csv'
PoliticalIdeology = pd.read_csv(path)
PoliticalIdeology
# Out:
#       GEOID winner  votes_R_2020  votes_D_2020  votes_third_party_2020  \
# 0      1001      R         19838          7503                     350
# 1      1003      R         83544         24578                    1229
# 2      1005      R          5622          4816                      68
# 3      1007      R          7525          1986                      74
# 4      1009      R         24711          2640                     209
# ...     ...    ...           ...           ...                     ...
# 3107  56037      R         12229          3823                     468
# 3108  56039      R          4341          9848                     344
# 3109  56041      R          7496          1591                     251
# 3110  56043      R          3245           651                      97
# 3111  56045      R          3107           360                      66
#
#       votes_total_2020  republican  republican_Rate
# 0                27691           1         0.716406
# ...

# %%
path = 'DataMerge/G-VaxHesitancy.csv'
VaxHesitancy = pd.read_csv(path)
VaxHesitancy
# Out:
#       GEOID  hesitancy  strong_hesitancy
# 0      1001       0.22              0.10
# 1      1003       0.20              0.10
# 2      1005       0.23              0.11
# 3      1007       0.24              0.12
# 4      1009       0.23              0.11
# ...     ...        ...               ...
# 3137  56037       0.31              0.17
# 3138  56039       0.29              0.15
# 3139  56041       0.31              0.17
# 3140  56043       0.32              0.17
# 3141  56045       0.32              0.17
#
# [3142 rows x 3 columns]

# %%
path = 'DataMerge/H-COVID.csv'
COVID = pd.read_csv(path)
COVID
# Out:
#       GEOID  Confirmed  Deaths  Incident_Rate  Case_Fatality_Ratio
# 0      1001       6675     102   11947.591688             1.528090
# 1      1003      20573     301    9215.890053             1.463083
# 2      1005       2239      55    9069.918172             2.456454
# 3      1007       2557      58   11418.237028             2.268283
# 4      1009       6469     133   11187.009304             2.055959
# ...     ...        ...     ...            ...                  ...
# 3261  90053       1521       4            NaN             0.262985
# 3262  90054          0       0            NaN                  NaN
# 3263  90055          0       0            NaN                  NaN
# 3264  90056          0       0            NaN                  NaN
# 3265  99999        103       3            NaN             2.912621
#
# [3266 rows x 5 columns]

# %%
path = 'DataMerge/I-INTERNET_SUBSCRIPTIONS.csv'
INTERNET_SUBSCRIPTIONS = pd.read_csv(path)
INTERNET_SUBSCRIPTIONS
# Out:
#                   Geographic Area Name  Rate_Total geqHighSchool  \
# 0                     Autauga, Alabama                  0.597574
# 1                     Baldwin, Alabama                  0.645614
# 2                     Barbour, Alabama                  0.522136
# 3                        Bibb, Alabama                  0.569612
# 4                      Blount, Alabama                  0.555102
# ...                                ...                       ...
# 3215  Vega Baja Municipio, Puerto Rico                  0.505831
# 3216    Vieques Municipio, Puerto Rico                  0.513307
# 3217   Villalba Municipio, Puerto Rico                  0.529839
# 3218    Yabucoa Municipio, Puerto Rico                  0.504818
# 3219      Yauco Municipio, Puerto Rico                  0.531095
#
#       Rate_Total geqBachelor  Rate_ComputerAdInternet_Whole  \
# 0                   0.180498                          0.853
# 1                   0.228780                          0.858
# ...

# %%
path = 'DataMerge/J-EMPLOYMENT.csv'
EMPLOYMENT = pd.read_csv(path)
EMPLOYMENT
# Out:
#                   Geographic Area Name  Rate_Unemployment_Whole  \
# 0                     Autauga, Alabama                    0.037
# 1                     Baldwin, Alabama                    0.043
# 2                     Barbour, Alabama                    0.092
# 3                        Bibb, Alabama                    0.073
# 4                      Blount, Alabama                    0.034
# ...                                ...                      ...
# 3215  Vega Baja Municipio, Puerto Rico                    0.174
# 3216    Vieques Municipio, Puerto Rico                    0.075
# 3217   Villalba Municipio, Puerto Rico                    0.219
# 3218    Yabucoa Municipio, Puerto Rico                    0.198
# 3219      Yauco Municipio, Puerto Rico                    0.202
#
#       Rate_Unemployment_White  Rate_Unemployment_Black  \
# 0                       0.034                    0.051
# 1                       0.038                    0.086
# ...

# %%
path = 'DataMerge/K-EDUCATION.csv'
EDUCATION = pd.read_csv(path)
EDUCATION
# Out:
#                   Geographic Area Name  Percent_White geqHighSchool  \
# 0                     Autauga, Alabama                        0.912
# 1                     Baldwin, Alabama                        0.919
# 2                     Barbour, Alabama                        0.786
# 3                        Bibb, Alabama                        0.844
# 4                      Blount, Alabama                        0.809
# ...                                ...                          ...
# 3215  Vega Baja Municipio, Puerto Rico                        0.704
# 3216    Vieques Municipio, Puerto Rico                        0.765
# 3217   Villalba Municipio, Puerto Rico                        0.790
# 3218    Yabucoa Municipio, Puerto Rico                        0.643
# 3219      Yauco Municipio, Puerto Rico                        0.731
#
#       Percent_White geqBachelor  Percent_Black geqHighSchool  \
# 0                         0.291                        0.789
# ...

# %%
path = 'DataMerge/L-BroadBoardSpeed.csv'
BroadBoardSpeed = pd.read_csv(path)
BroadBoardSpeed
# Out:
#       GEOID  fixed_avg_d_mbps_wt  fixed_avg_u_mbps_wt  fixed_avg_lat_wt  \
# 0      1001           155.893636            77.383649         23.550424
# 1      1003           122.081455            53.476077         46.965039
# 2      1005           113.287736            11.731600         62.774059
# 3      1007            46.402450            33.444540        103.175520
# 4      1009            83.130446            19.635431         38.061094
# ...     ...                  ...                  ...               ...
# 3197  72151            34.647772             7.279017         35.837315
# 3198  72153            46.942987             7.725302         34.334703
# 3199  78010            27.823811             8.965607         20.848733
# 3200  78020            22.055864             8.717722         26.484169
# 3201  78030            30.624871             6.874817         18.069549
#
#       mobile_avg_d_mbps_wt  mobile_avg_u_mbps_wt  mobile_avg_lat_wt
# ...

# %%
path = 'DataMerge/M-SocialVulnerabilityIndex.csv'
SocialVulnerabilityIndex = pd.read_csv(path)
SocialVulnerabilityIndex
# Out:
#       GEOID     AREA_SQMI     DENSITY  EP_POV  EP_AGE65  EP_DISABL  EP_MINRTY  \
# 0      1001    594.443459   92.859967   0.154     0.146      0.193      0.250
# 1      1003   1589.793007  130.901947   0.106     0.195      0.140      0.170
# 2      1005    885.001636   29.132150   0.289     0.180      0.222      0.539
# 3      1007    622.461089   36.190214   0.140     0.163      0.167      0.254
# 4      1009    644.830460   89.395591   0.144     0.178      0.142      0.129
# ...     ...           ...         ...     ...       ...        ...        ...
# 3137  56037  10426.975725    4.231045   0.120     0.107      0.123      0.204
# 3138  56039   3996.844622    5.769301   0.071     0.136      0.070      0.184
# 3139  56041   2081.719807    9.899987   0.125     0.121      0.172      0.125
# 3140  56043   2238.672972    3.631169   0.124     0.207      0.149      0.180
# 3141  56045   2398.003891    2.960796   0.174     0.189      0.144      0.089
#
# ...

# %%
path = 'DataMerge/N-Traffic.csv'
Traffic = pd.read_csv(path)
Traffic
# Out:
#            Geographic Area Name   TCI
# 0            New York, New York  52.6
# 1               Kings, New York  34.5
# 2               Bronx, New York  29.5
# 3     San Francisco, California  31.7
# 4              Queens, New York  23.8
# ...                         ...   ...
# 3137            Lincoln, Kansas   0.0
# 3138          Lincoln, Kentucky   0.0
# 3139             Lincoln, Maine   0.0
# 3140         Lincoln, Minnesota   0.0
# 3141          Lincoln, Missouri   0.0
#
# [3142 rows x 2 columns]

# %%
path = 'DataMerge/O-VaccineCoverageIndex.csv'
VaccineCoverageIndex = pd.read_csv(path)
VaccineCoverageIndex
# Out:
#       GEOID  Th1_Historic_Undervaccination  Th2_Sociodemographic_Barriers  \
# 0      1001                       0.419612                       0.231455
# 1      1003                       0.228590                       0.150271
# 2      1005                       0.505571                       0.991404
# 3      1007                       0.410060                       0.888252
# 4      1009                       0.440306                       0.716014
# ...     ...                            ...                            ...
# 3137  56037                       0.951926                       0.201210
# 3138  56039                       0.913403                       0.115568
# 3139  56041                       0.942057                       0.152499
# 3140  56043                       0.980579                       0.375040
# 3141  56045                       0.991404                       0.090099
#
#       Th3_Resource_constrained_Healthcare_System  \
# ...

# %%
path = 'DataMerge/P-VaccineFaclility.csv'
VaccineFaclility = pd.read_csv(path)
VaccineFaclility
# Out:
#       GEOID  FQHC Count  FacDensity10K  HOPD count  PHMCY Count  RUHC Count
# 0      1001           1         2.1479           1           10           0
# 1      1003           5         2.5086           3           48           0
# 2      1005           2         3.2407           1            5           0
# 3      1007           6         4.9120           1            4           0
# 4      1009           1         2.9399           0            8           8
# ...     ...         ...            ...         ...          ...         ...
# 3103  56037           1         2.1255           1            6           1
# 3104  56039           0         2.1309           1            4           0
# 3105  56041           1         3.4609           1            5           0
# 3106  56043           0         1.2812           0            1           0
# 3107  56045           0         2.8873           0            2           0
#
# [3108 rows x 6 columns]

# %%
path = 'DataMerge/Q-FCC.csv'
FCC = pd.read_csv(path)
FCC
# Out:
#       GEOID  Rate_poor_fair_health  provcount_b  provcount_c  \
# 0      1001                  0.228           10            9
# 1      1003                  0.127           20           13
# 2      1005                  0.234           13            9
# 3      1007                  0.179            7            6
# 4      1009                  0.242           12           11
# ...     ...                    ...          ...          ...
# 3137  56037                  0.142           18           11
# 3138  56039                  0.059           11            8
# 3139  56041                  0.135           12           10
# 3140  56043                  0.106            9            7
# 3141  56045                  0.162           10            8
#
#       injury_deaths_per_100000
# 0                         73.3
# 1                         74.5
# 2                         56.1
# 3                         80.8
# 4                         91.9
# ...                        ...
# ...

# %%
path = 'DataMerge/R-HealthRanking.csv'
HealthRanking = pd.read_csv(path)
HealthRanking
# Out:
#       GEOID  Segregation index  \
# 0      2000          51.512262
# 1      2013                NaN
# 2      2016                NaN
# 3      2020          38.379522
# 4      2050          13.872255
# ...     ...                ...
# 3042  54101                NaN
# 3043  54103          61.871617
# 3044  54105                NaN
# 3045  54107          54.575574
# 3046  54109          47.866961
#
#       Average Traffic Volume per Meter of Major Roadways  % Vaccinated  \
# 0                                            217.596161           35.0
# 1                                              0.000000            NaN
# 2                                              0.000000            NaN
# 3                                            462.572067           38.0
# 4                                              4.727448           10.0
# ...                                                 ...            ...
# 3042                                           0.000000           26.0
# ...

# %%
path = 'DataMerge/S-ADI.csv'
ADI = pd.read_csv(path)
ADI
# Out:
#       GEOID  sdi_score
# 0      1001         22
# 1      1003         15
# 2      1005         88
# 3      1007         31
# 4      1009         36
# ...     ...        ...
# 3137  56037         20
# 3138  56039         13
# 3139  56041         17
# 3140  56043         27
# 3141  56045         21
#
# [3142 rows x 2 columns]

# %%
path = 'DataMerge/U-FluVax.csv'
FluVax = pd.read_csv(path)
FluVax
# Out:
#       GEOID  urban  FluWhole  FluWhite  FluBlack  FluAAWhole  FluAAWhite  \
# 0      1001      1      0.42      0.44      0.27        0.42        0.44
# 1      1003      0      0.47      0.48      0.27        0.46        0.47
# 2      1005      0      0.35      0.38      0.29        0.36        0.37
# 3      1007      1      0.31      0.33      0.19        0.33        0.35
# 4      1009      1      0.39      0.39      0.25        0.40        0.40
# ...     ...    ...       ...       ...       ...         ...         ...
# 3215  72145      1      0.15       NaN       NaN        0.14         NaN
# 3216  72147      0      0.18      0.55       NaN        0.18         NaN
# 3217  72149      1      0.11       NaN       NaN        0.11         NaN
# 3218  72151      1      0.17       NaN       NaN        0.18         NaN
# 3219  72153      1      0.16       NaN       NaN        0.16         NaN
#
#       FluAABlack
# 0           0.31
# 1           0.31
# 2           0.30
# 3           0.22
# ...

# %% [markdown]
# # County Race Vaccine Rate

# %%
import pickle

import pandas as pd
import numpy as np

path = 'CountyVaccine/RaceVaccineBackup/STATE_VACCINE_2021-04-07.p'

with open(path, 'rb' ) as f:
    STATE_VACCINE = pickle.load(f)
    
CountyRaceVaccine = pd.concat([v for k,v in STATE_VACCINE.items()])
print(CountyRaceVaccine.shape)
CountyRaceVaccine
# Out:
# (1296, 34)
#          State     County   Geographic Area Name        Date     Numb_White  \
# 0   California    Alameda    Alameda, California  2021-04-06  186256.131102
# 1   California     Amador     Amador, California  2021-04-06   10295.982504
# 2   California      Butte      Butte, California  2021-04-06   38755.387296
# 3   California  Calaveras  Calaveras, California  2021-04-06    8185.189474
# 4   California     Colusa     Colusa, California  2021-04-06    1767.066692
# ..         ...        ...                    ...         ...            ...
# 31      Oregon   Columbia       Columbia, Oregon         NaN    8522.000000
# 32      Oregon    Clatsop        Clatsop, Oregon         NaN    6313.000000
# 33      Oregon  Clackamas      Clackamas, Oregon         NaN   70058.000000
# 34      Oregon     Benton         Benton, Oregon         NaN   22067.000000
# 35      Oregon      Baker          Baker, Oregon         NaN    5669.000000
#
# ...

# %%
CountyRaceVaccine.columns
# Out:
# Index(['State', 'County', 'Geographic Area Name', 'Date', 'Numb_White',
#        'Rate_White', 'Numb_Black', 'Rate_Black', 'Total_AIndA', 'Total_AIndAC',
#        'Total_Asian', 'Total_AsianC', 'Total_Black', 'Total_BlackC',
#        'Total_White', 'Total_WhiteC', 'Total_Whole',
#        'cumulative_at_least_one_dose', 'Rate_Parity', 'Numb_Asian',
#        'Rate_Asian', 'Numb_AIndA', 'Rate_AIndA', 'Rate_BlackC', 'Rate_WhiteC',
#        'Rate_AsianC', 'Rate_ParityC', 'Numb_Hispa', 'Numb_NaHis', 'Numb_Other',
#        'Rate_AIndAC', 'Rate_Hispa', 'Rate_NaHis', 'Rate_Other'],
#       dtype='object')

# %%
CountyRaceVaccine = CountyRaceVaccine.replace(['Suppressed', '-'], np.nan)

cols = ['State', 'County', 'Geographic Area Name', 'Numb_White', 'Rate_White',
         'Numb_Black', 'Rate_Black', 'Numb_Asian', 'Rate_Asian', 'Rate_Parity']

CountyRaceVaccine = CountyRaceVaccine[cols]

def process_value(v):
    if type(v) == float or type(v) == int:
        return float(v)
    
    if ',' in v:
        v = v.replace(',', '')
        
    return float(v)


for i in CountyRaceVaccine.columns[3:]:
    print(i)
    CountyRaceVaccine[i] = CountyRaceVaccine[i].apply(process_value)

CountyRaceVaccine
# Out:
# Numb_White
# Rate_White
# Numb_Black
# Rate_Black
# Numb_Asian
# Rate_Asian
# Rate_Parity
#          State     County   Geographic Area Name     Numb_White  Rate_White  \
# 0   California    Alameda    Alameda, California  186256.131102    0.226151
# 1   California     Amador     Amador, California   10295.982504    0.288921
# 2   California      Butte      Butte, California   38755.387296    0.206429
# 3   California  Calaveras  Calaveras, California    8185.189474    0.196043
# 4   California     Colusa     Colusa, California    1767.066692    0.090019
# ..         ...        ...                    ...            ...         ...
# 31      Oregon   Columbia       Columbia, Oregon    8522.000000    0.176118
# 32      Oregon    Clatsop        Clatsop, Oregon    6313.000000    0.169545
# 33      Oregon  Clackamas      Clackamas, Oregon   70058.000000    0.188496
# 34      Oregon     Benton         Benton, Oregon   22067.000000    0.274066
# ...

# %% [markdown]
# ## Z1. Merge First Trial

# %%
set_all = set(INTERNET_SUBSCRIPTIONS['Geographic Area Name'].unique())

print(len(set_all))

set_vaccine = set(CountyRaceVaccine['Geographic Area Name'].unique())

print(len(set_vaccine))
# Out:
# 3220
# 1296

# %%
# def change_name(name):
#     if name in change_county_names:
#         return change_county_names[name]
#     else:
#         return name
    
# def get_county(county_state):
#     return county_state.split(', ')[0]


    
# CountyRaceVaccine['Geographic Area Name'] = CountyRaceVaccine['Geographic Area Name'].apply(change_name)
# CountyRaceVaccine['County'] = CountyRaceVaccine['Geographic Area Name'].apply(get_county)

CountyRaceVaccine.head()
# Out:
#         State     County   Geographic Area Name     Numb_White  Rate_White  \
# 0  California    Alameda    Alameda, California  186256.131102    0.226151
# 1  California     Amador     Amador, California   10295.982504    0.288921
# 2  California      Butte      Butte, California   38755.387296    0.206429
# 3  California  Calaveras  Calaveras, California    8185.189474    0.196043
# 4  California     Colusa     Colusa, California    1767.066692    0.090019
#
#      Numb_Black  Rate_Black  Numb_Asian  Rate_Asian  Rate_Parity
# 0  42389.339979    0.229917         NaN         NaN    -0.003766
# 1     66.627963    0.062503         NaN         NaN     0.226418
# 2    508.553106    0.122307         NaN         NaN     0.084122
# 3     61.136490    0.122764         NaN         NaN     0.073279
# 4     29.238932    0.103684         NaN         NaN    -0.013665

# %%
CountyRaceVaccine.columns
# Out:
# Index(['State', 'County', 'Geographic Area Name', 'Numb_White', 'Rate_White',
#        'Numb_Black', 'Rate_Black', 'Numb_Asian', 'Rate_Asian', 'Rate_Parity'],
#       dtype='object')

# %% [markdown]
# ## Z2. Merge Together

# %%
import pandas as pd
from state_race_scraper import us_popu
import importlib


path_cc  = 'Data/cc-est2019-alldata.csv'
path_acs = 'Data/ACS/TYPES OF INTERNET SUBSCRIPTIONS BY SELECTED CHARACTERISTICS/ACSST5Y2019.S2802_2021-03-20T111825/ACSST5Y2019.S2802_data_with_overlays_2021-03-20T111812.csv'


US_COUNTY_POPULATION = us_popu.get_US_COUNTY_POPULATION(path_cc, path_acs)

print(US_COUNTY_POPULATION.shape)
US_COUNTY_POPULATION.head()
# Out:
# (3142, 13)
#    GEOID    State   County Geographic Area Name  Total_Whole  Total_White  \
# 0  01001  Alabama  Autauga     Autauga, Alabama        55869        42607
# 1  01003  Alabama  Baldwin     Baldwin, Alabama       223234       195198
# 2  01005  Alabama  Barbour     Barbour, Alabama        24686        12134
# 3  01007  Alabama     Bibb        Bibb, Alabama        22394        17191
# 4  01009  Alabama   Blount      Blount, Alabama        57826        55412
#
#    Total_Black  Total_AIndA  Total_Asian  Total_WhiteC  Total_BlackC  \
# 0        11237          266          656         43563         11784
# 1        19593         1742         2380        199103         21354
# 2        11906          170          116         12380         12117
# 3         4763          103           48         17420          4907
# 4          978          370          185         56167          1276
#
#    Total_AIndAC  Total_AsianC
# 0           575           950
# ...

# %%
set_all = set(US_COUNTY_POPULATION['Geographic Area Name'].unique())

print(len(set_all))

set_vaccine = set(CountyRaceVaccine['Geographic Area Name'].unique())

print(len(set_vaccine))

not_matched = set_vaccine - set_all
not_matched = [{'County':i.split(', ')[0], 'State':i.split(', ')[-1], 'Geographic Area Name':i} for i in not_matched ]

pd.DataFrame(not_matched)
# Out:
# 3142
# 1296
# Empty DataFrame
# Columns: []
# Index: []

# %%
cols = [i for i in US_COUNTY_POPULATION.columns if i not in ['State', 'County']]
US_COUNTY_POPULATION = US_COUNTY_POPULATION[cols]
print(US_COUNTY_POPULATION.shape)
print(CountyRaceVaccine.shape)
MergedCounty = pd.merge(CountyRaceVaccine, US_COUNTY_POPULATION, on='Geographic Area Name')
print(MergedCounty.shape)
# Out:
# (3142, 11)
# (1296, 10)
# (1296, 20)

# %% [markdown]
# ## Z3. Get Race Rate

# %%
MergedCounty.columns
# Out:
# Index(['State', 'County', 'Geographic Area Name', 'Numb_White', 'Rate_White',
#        'Numb_Black', 'Rate_Black', 'Numb_Asian', 'Rate_Asian', 'Rate_Parity',
#        'GEOID', 'Total_Whole', 'Total_White', 'Total_Black', 'Total_AIndA',
#        'Total_Asian', 'Total_WhiteC', 'Total_BlackC', 'Total_AIndAC',
#        'Total_AsianC'],
#       dtype='object')

# %%
FinalMergedCounty = MergedCounty
print(FinalMergedCounty.shape)
FinalMergedCounty.head()
# Out:
# (1296, 20)
#         State     County   Geographic Area Name     Numb_White  Rate_White  \
# 0  California    Alameda    Alameda, California  186256.131102    0.226151
# 1  California     Amador     Amador, California   10295.982504    0.288921
# 2  California      Butte      Butte, California   38755.387296    0.206429
# 3  California  Calaveras  Calaveras, California    8185.189474    0.196043
# 4  California     Colusa     Colusa, California    1767.066692    0.090019
#
#      Numb_Black  Rate_Black  Numb_Asian  Rate_Asian  Rate_Parity  GEOID  \
# 0  42389.339979    0.229917         NaN         NaN    -0.003766  06001
# 1     66.627963    0.062503         NaN         NaN     0.226418  06005
# 2    508.553106    0.122307         NaN         NaN     0.084122  06007
# 3     61.136490    0.122764         NaN         NaN     0.073279  06009
# 4     29.238932    0.103684         NaN         NaN    -0.013665  06011
#
# ...

# %%
FinalMergedCounty['Rate_Parity'] = FinalMergedCounty['Rate_White'] - FinalMergedCounty['Rate_Black']
# FinalMergedCounty['Rate_Parity_Ratio']  = FinalMergedCounty['Rate_White'] / FinalMergedCounty['Rate_Black']

FinalMergedCounty = FinalMergedCounty.replace([np.inf, -np.inf], np.nan)

FinalMergedCounty.head()
# Out:
#         State     County   Geographic Area Name     Numb_White  Rate_White  \
# 0  California    Alameda    Alameda, California  186256.131102    0.226151
# 1  California     Amador     Amador, California   10295.982504    0.288921
# 2  California      Butte      Butte, California   38755.387296    0.206429
# 3  California  Calaveras  Calaveras, California    8185.189474    0.196043
# 4  California     Colusa     Colusa, California    1767.066692    0.090019
#
#      Numb_Black  Rate_Black  Numb_Asian  Rate_Asian  Rate_Parity  GEOID  \
# 0  42389.339979    0.229917         NaN         NaN    -0.003766  06001
# 1     66.627963    0.062503         NaN         NaN     0.226418  06005
# 2    508.553106    0.122307         NaN         NaN     0.084122  06007
# 3     61.136490    0.122764         NaN         NaN     0.073279  06009
# 4     29.238932    0.103684         NaN         NaN    -0.013665  06011
#
#    Total_Whole  Total_White  Total_Black  Total_AIndA  Total_Asian  \
# ...

# %%
# from state_race_scraper.diagnose_rate import diagnose_Rate

# diagnose_Rate(FinalMergedCounty)

# %% [markdown]
# # Y. Merge All the Data

# %%
FinalMergedCounty2 = pd.merge(FinalMergedCounty, ACS_Table, on='Geographic Area Name')
# FinalMergedCounty2
FinalMergedCounty2_5 = pd.merge(FinalMergedCounty2, Traffic, on='Geographic Area Name')

# %%
# BroadBoardSpeed, VaccineCoverageIndex, VaccineFaclility

FinalMergedCounty3 = pd.merge(FinalMergedCounty2_5, BroadBoardSpeed, on='GEOID')
FinalMergedCounty4 = pd.merge(FinalMergedCounty3, VaccineCoverageIndex, on='GEOID')
FinalMergedCounty5 = pd.merge(FinalMergedCounty4, VaccineFaclility, on='GEOID')

# %%
FinalMergedCounty6 = pd.merge(FinalMergedCounty5, COVID, on='GEOID')
FinalMergedCounty7 = pd.merge(FinalMergedCounty6, PoliticalIdeology, on='GEOID')

# %%
FinalMergedCounty8 = pd.merge(FinalMergedCounty7, INCOME, on='GEOID')
FinalMergedCounty9 = pd.merge(FinalMergedCounty8, SocialVulnerabilityIndex, on='GEOID')
FinalMergedCounty10 = pd.merge(FinalMergedCounty9, FCC, on='GEOID')
FinalMergedCounty11 = pd.merge(FinalMergedCounty10, HealthRanking, on='GEOID')
FinalMergedCounty12 = pd.merge(FinalMergedCounty11, ADI, on='GEOID')
FinalMergedCounty13 = pd.merge(FinalMergedCounty12, SDI, on='GEOID')
# FinalMergedCounty14 = pd.merge(FinalMergedCounty13, Age75Above, on='GEOID', how='left')
FinalMergedCounty13_5 = pd.merge(FinalMergedCounty13, AgeDisparity, on='GEOID')
FinalMergedCounty13_6 = pd.merge(FinalMergedCounty13_5, FluVax, on='GEOID')
FinalMergedCounty13_7 = pd.merge(FinalMergedCounty13_6, Disparity_in_Pysch, on='GEOID')
FinalMergedCounty14 = pd.merge(FinalMergedCounty13_7, Disparity_in_SexDisparity, on='GEOID')

# %%
print(FinalMergedCounty14.shape)
print(list(FinalMergedCounty14.columns))
# Out:
# (1275, 162)
# ...

# %%
FinalMergedCounty14.shape
# Out:
# (1293, 150)

# %% [markdown]
# ## Rename Columns

# %%
names = [

'State', 'County', 'AreaName', '##ID',

'Numb_White', 'Rate_White', 'Numb_Black', 'Rate_Black', 'Numb_Asian', 'Rate_Asian', 'Rate_Diff', '##COVID-VAX',

'FIPS', '##ID',

'Total_Whole', 'Total_White', 'Total_Black', 'Total_AIndA', 'Total_Asian', '##POPULATION-Alone',

'Total_WhiteC', 'Total_BlackC', 'Total_AIndAC', 'Total_AsianC', '##POPULATION-Combine',

'HighSchool_White', 'Bachelor_White', 'HighSchool_Black', 'Bachelor_Black', 'HighSchool_AIndA', 'Bachelor_AIndA', 'HighSchool_Aisan', 'Bachelor_Asian', 'HighSchool_Diff', 'Bachelor_Diff', 'HighSchool_Whole', 'Bachelor_Whole',  '##EDU',

'CI_Whole', 'CI_White', 'CI_Black', 'CI_AIndA', 'CI_Asian', '##Tech-INT-CI',

'CnoI_Whole', 'CnoI_White', 'CnoI_Black', 'CnoI_AIndA', 'CnoI_Asian', '##Tech-INT-CnoI',

'noC_Whole', 'noC_White', 'noC_Black', 'noC_AIndA', 'noC_Asian', 'CI_Diff', 'noC_Diff', '##Tech-INT-noC',

'Unemployment_Whole', 'Unemployment_White', 'Unemployment_Black', 'Unemployment_AIndA', 'Unemployment_Asian', 'Unemployment_Diff', '##EMPLOY-noC',

'TCI', '##Traffic',

'fixed_d', 'fixed_u', 'fixed_lat','##Tech-WebSpeed-Fix',

'mobile_d', 'mobile_u', 'mobile_lat', '##Tech-WebSpeed-Mobile',

'undervaccination', 'barriers', 'resource_constrained', 'inaccessibility', 'irregular_behavior', 'CVAC', '##Vax-Coverage',

'FQHC', 'FacDensity10K', 'HOPD', 'PHMCY', 'RUHC','##HealthCare-Facility',

'cases', 'deaths', 'Incident_rate', 'mortality', '##Covid',

'winner', 'votes_R', 'votes_D', 'votes_3party', 'votes_total', 'republican', 'republican_rate', '##Politics',

'MeanIncome', 'MeanIncome_White', 'MeanIncome_Black', 'MeanIncome_Diff',  '##Income-Mean',

'MedianIncome', 'MedianIncome_White', 'MedianIncome_Black', 'MedianIncome_Diff', '##Income-Median',

'AREA_SQMI', 'DENSITY', '##COUNTY',

'EP_POV', '##INCOME',

'Age65', '##AGE',

'EP_DISABL', 'EP_MINRTY', 'EP_LIMENG', 'EP_NOVEH', '##INDEX',


'RPL_THEME1', 'RPL_THEME2', 'RPL_THEME3', 'RPL_THEME4', 'RPL_THEMES', '##INDEX',

'Rate_poorhealth','##INDEX',

'Num_providerb', 'Num_providerc', '##TECH',

'injury_deaths',  '##SAFT',

'Segregation', '##INDEX',

'AvgTrafficVolume',  '##Traffic',

'fluvax', 'fluvax_Asian', 'fluvax_Black', 'fluvax_White', '##VAX',

'Rate_viocrime', '##SAFT',

'ADIMean', 'ADIStd', 'SDI', '##INDEX',


'Above75_WhiteRate', 'Above75_BlackRate', 'Above75_Disparity', 'Above75_Whole', '##AGE',
'Above65_WhiteRate', 'Above65_BlackRate', 'Above65_Disparity', 'Above65_Whole', '##AGE',
'Below19_WhiteRate', 'Below19_BlackRate', 'Below19_Disparity', 'Below19_Whole', '##AGE',
'Below24_WhiteRate', 'Below24_BlackRate', 'Below24_Disparity', 'Below24_Whole', '##AGE',
'Below29_WhiteRate', 'Below29_BlackRate', 'Below29_Disparity', 'Below29_Whole', '##AGE',
'Below39_WhiteRate', 'Below39_BlackRate', 'Below39_Disparity', 'Below39_Whole', '##AGE',

'urban',  'FluWhole', 'FluWhite', 'FluBlack', 'FluAAWhole', 'FluAAWhite', 'FluAABlack', '##VAX',
# 'urban', 'FluWhole', 'FluWhite',  'FluBlack', '##VAX',
    
    
'racial_bias', 'racial_explicit_diff', 'racial_n_bias_obs', 'racial_n_explicit_obs', 'racial_weighted_bias', 'racial_weighted_explicit_diff', '##RacialDisparity',
    'sex_bias', 'sex_explicit', 'sex_n_bias_obs', 'sex_n_explicit_obs', 'sex_weighted_bias', 'sex_weighted_explicit', '##SexualDisparity',
] 

from pprint import pprint

new_name_list = [i for i in names if i[:2] != '##']
assert len(new_name_list) == len(FinalMergedCounty14.columns)
new_names = dict(zip(FinalMergedCounty14.columns, new_name_list))


new_names
# Out:
# {'State': 'State',
#  'County': 'County',
#  'Geographic Area Name': 'AreaName',
#  'Numb_White': 'Numb_White',
#  'Rate_White': 'Rate_White',
#  'Numb_Black': 'Numb_Black',
#  'Rate_Black': 'Rate_Black',
#  'Numb_Asian': 'Numb_Asian',
#  'Rate_Asian': 'Rate_Asian',
#  'Rate_Parity': 'Rate_Diff',
#  'GEOID': 'FIPS',
#  'Total_Whole': 'Total_Whole',
#  'Total_White': 'Total_White',
#  'Total_Black': 'Total_Black',
#  'Total_AIndA': 'Total_AIndA',
#  'Total_Asian': 'Total_Asian',
#  'Total_WhiteC': 'Total_WhiteC',
#  'Total_BlackC': 'Total_BlackC',
#  'Total_AIndAC': 'Total_AIndAC',
#  'Total_AsianC': 'Total_AsianC',
#  'Rate_White geqHighSchool': 'HighSchool_White',
#  'Rate_White geqBachelor': 'Bachelor_White',
#  'Rate_Black geqHighSchool': 'HighSchool_Black',
#  'Rate_Black geqBachelor': 'Bachelor_Black',
#  'Rate_AIndA geqHighSchool': 'HighSchool_AIndA',
#  'Rate_AIndA geqBachelor': 'Bachelor_AIndA',
#  'Rate_Asian geqHighSchool': 'HighSchool_Aisan',
# ...

# %%
FinalMergedCounty15 = FinalMergedCounty14.rename(columns = new_names)

FinalMergedCounty15
# Out:
#            State     County               AreaName     Numb_White  Rate_White  \
# 0     California    Alameda    Alameda, California  186256.131102    0.226151
# 1     California     Amador     Amador, California   10295.982504    0.288921
# 2     California      Butte      Butte, California   38755.387296    0.206429
# 3     California  Calaveras  Calaveras, California    8185.189474    0.196043
# 4     California     Colusa     Colusa, California    1767.066692    0.090019
# ...          ...        ...                    ...            ...         ...
# 1270      Oregon   Columbia       Columbia, Oregon    8522.000000    0.176118
# 1271      Oregon    Clatsop        Clatsop, Oregon    6313.000000    0.169545
# 1272      Oregon  Clackamas      Clackamas, Oregon   70058.000000    0.188496
# 1273      Oregon     Benton         Benton, Oregon   22067.000000    0.274066
# 1274      Oregon      Baker          Baker, Oregon    5669.000000    0.375232
#
# ...

# %%
end_index_list = []
for idx, v in enumerate(names):
    if v[:2] == '##':
        end_index_list.append(idx)
        
end_index_list

start_index_list = [-1] + end_index_list[:-1]
start_index_list



L = []
for idx in range(len(end_index_list)):
    start_idx = start_index_list[idx] + 1
    
    end_idx   = end_index_list[idx]
    
    label = names[end_idx]
    
    # print(start_idx, end_idx)
    cols = names[start_idx: end_idx]
    
    L.append([label, cols])
    # print(label, cols)
# L


# dict(zip(start_index_list, end_index_list))
# L

VariableDict = {}

for label,  cols in L:
    
    if label not in VariableDict:
        VariableDict[label] = cols
    else:
        VariableDict[label] = VariableDict[label] + cols
    
    
    
VariableDict
# Out:
# {'##ID': ['State', 'County', 'AreaName', 'FIPS'],
#  '##COVID-VAX': ['Numb_White',
#   'Rate_White',
#   'Numb_Black',
#   'Rate_Black',
#   'Numb_Asian',
#   'Rate_Asian',
#   'Rate_Diff'],
#  '##POPULATION-Alone': ['Total_Whole',
#   'Total_White',
#   'Total_Black',
#   'Total_AIndA',
#   'Total_Asian'],
#  '##POPULATION-Combine': ['Total_WhiteC',
#   'Total_BlackC',
#   'Total_AIndAC',
#   'Total_AsianC'],
#  '##EDU': ['HighSchool_White',
#   'Bachelor_White',
#   'HighSchool_Black',
#   'Bachelor_Black',
#   'HighSchool_AIndA',
#   'Bachelor_AIndA',
#   'HighSchool_Aisan',
#   'Bachelor_Asian',
#   'HighSchool_Diff',
#   'Bachelor_Diff',
#   'HighSchool_Whole',
#   'Bachelor_Whole'],
#  '##Tech-INT-CI': ['CI_Whole', 'CI_White', 'CI_Black', 'CI_AIndA', 'CI_Asian'],
#  '##Tech-INT-CnoI': ['CnoI_Whole',
#   'CnoI_White',
#   'CnoI_Black',
#   'CnoI_AIndA',
#   'CnoI_Asian'],
#  '##Tech-INT-noC': ['noC_Whole',
#   'noC_White',
#   'noC_Black',
#   'noC_AIndA',
#   'noC_Asian',
# ...

# %%
new_columns = sum([v for k, v in VariableDict.items()], [])
print(new_columns)
FinalMergedCounty16 = FinalMergedCounty15[new_columns]
# Out:
# ['State', 'County', 'AreaName', 'FIPS', 'Numb_White', 'Rate_White', 'Numb_Black', 'Rate_Black', 'Numb_Asian', 'Rate_Asian', 'Rate_Diff', 'Total_Whole', 'Total_White', 'Total_Black', 'Total_AIndA', 'Total_Asian', 'Total_WhiteC', 'Total_BlackC', 'Total_AIndAC', 'Total_AsianC', 'HighSchool_White', 'Bachelor_White', 'HighSchool_Black', 'Bachelor_Black', 'HighSchool_AIndA', 'Bachelor_AIndA', 'HighSchool_Aisan', 'Bachelor_Asian', 'HighSchool_Diff', 'Bachelor_Diff', 'HighSchool_Whole', 'Bachelor_Whole', 'CI_Whole', 'CI_White', 'CI_Black', 'CI_AIndA', 'CI_Asian', 'CnoI_Whole', 'CnoI_White', 'CnoI_Black', 'CnoI_AIndA', 'CnoI_Asian', 'noC_Whole', 'noC_White', 'noC_Black', 'noC_AIndA', 'noC_Asian', 'CI_Diff', 'noC_Diff', 'Unemployment_Whole', 'Unemployment_White', 'Unemployment_Black', 'Unemployment_AIndA', 'Unemployment_Asian', 'Unemployment_Diff', 'TCI', 'AvgTrafficVolume', 'fixed_d', 'fixed_u', 'fixed_lat', 'mobile_d', 'mobile_u', 'mobile_lat', 'undervaccination', 'barriers', 'resource_const
# ...

# %%
# FinalMergedCounty5 = FinalMergedCounty5[FinalMergedCounty5['State'] != 'Colorado']
# FinalMergedCounty5.shape


FinalMergedCounty16
# Out:
#            State     County               AreaName   FIPS     Numb_White  \
# 0     California    Alameda    Alameda, California  06001  186256.131102
# 1     California     Amador     Amador, California  06005   10295.982504
# 2     California      Butte      Butte, California  06007   38755.387296
# 3     California  Calaveras  Calaveras, California  06009    8185.189474
# 4     California     Colusa     Colusa, California  06011    1767.066692
# ...          ...        ...                    ...    ...            ...
# 1270      Oregon   Columbia       Columbia, Oregon  41009    8522.000000
# 1271      Oregon    Clatsop        Clatsop, Oregon  41007    6313.000000
# 1272      Oregon  Clackamas      Clackamas, Oregon  41005   70058.000000
# 1273      Oregon     Benton         Benton, Oregon  41003   22067.000000
# 1274      Oregon      Baker          Baker, Oregon  41001    5669.000000
#
#       Rate_White    Numb_Black  Rate_Black  Numb_Asian  Rate_Asian  ...  \
# ...

# %%
cols = list(FinalMergedCounty16.columns)
print(len(cols))
print(cols)
# Out:
# 162
# ...

# %%
# FinalMergedCounty16.index

# %%
T = FinalMergedCounty16

# Diff: White - Black
T.loc[T.index, 'fluvax_Diff'] = T['fluvax_White'] - T['fluvax_Black']
T.loc[T.index, 'CnoI_Diff']   = T['CnoI_White'] - T['CnoI_Black']






T.loc[T.index, 'Vax_Avg']= (T['Rate_White'] * T['Total_White'] + T['Rate_Black'] * T['Total_Black'] )/ (T['Total_White'] + T['Total_Black'])
# Average meams Black and White
# Whole means all races, 
T.loc[T.index, 'Vax_Disparity']= T['Rate_Diff'] / T['Vax_Avg']
# Disparity



# Diff: White - Black
T.loc[T.index, 'FluDiff'] = T['FluWhite'] - T['FluBlack']
T.loc[T.index, 'FluAvg']= (T['FluWhite'] * T['Total_White'] + T['FluBlack'] * T['Total_Black'] )/ (T['Total_White'] + T['Total_Black'])
T.loc[T.index, 'FluDisparity']= T['FluDiff'] / T['FluAvg']


T.loc[T.index, 'FluAADiff'] = T['FluAAWhite'] - T['FluAABlack']
T.loc[T.index, 'FluAAAvg']= (T['FluAAWhite'] * T['Total_White'] + T['FluAABlack'] * T['Total_Black'] )/ (T['Total_White'] + T['Total_Black'])
T.loc[T.index, 'FluAADisparity']= T['FluAADiff'] / T['FluAAAvg']
# Out:
# /Users/floydluo/opt/miniconda3/envs/ox/lib/python3.9/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/floydluo/opt/miniconda3/envs/ox/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
for i in ['fluvax', 'HighSchool', 'Bachelor', 'CI', 'CnoI', 'noC', 'Unemployment']:

    
    T.loc[T.index, i+'_Avg']= (T[i+ '_White'] * T['Total_White'] + T[i+'_Black'] * T['Total_Black'] )/ (T['Total_White'] + T['Total_Black'])
    # Whole means all races, Average meams Black and White
    T.loc[T.index, i+'_Disparity']= T[i+'_Diff'] / T[i+ '_Avg']
    # Disparity
    print('"'+i+'_Avg' + '"', ',', '"'+i+'_Disparity'+ '"')
# Out:
# "fluvax_Avg" , "fluvax_Disparity"
# "HighSchool_Avg" , "HighSchool_Disparity"
# "Bachelor_Avg" , "Bachelor_Disparity"
# "CI_Avg" , "CI_Disparity"
# "CnoI_Avg" , "CnoI_Disparity"
# "noC_Avg" , "noC_Disparity"
# "Unemployment_Avg" , "Unemployment_Disparity"

# %%
for i in ['MeanIncome', 'MedianIncome',]:

    
    # T.loc[T.index, i+'_Avg']= (T[i+ '_White'] * T['Total_White'] + T[i+'_Black'] * T['Total_Black'] )/ (T['Total_White'] + T['Total_Black'])
    # Whole means all races, Average meams Black and White
    T.loc[T.index, i+'_DisparityB']= T[i+'_Diff'] / T[i+ '_Black']
    T.loc[T.index, i+'_Disparity']= T[i+'_Diff'] / T[i]
    # Disparity
    print('"'+i+'_Disparity'+ '"')
# Out:
# "MeanIncome_Disparity"
# "MedianIncome_Disparity"

# %%
[i for i in T.columns if 'urban' in i]
# Out:
# ['urban']

# %%
cols = [ 
'State', 'County', 'AreaName', 'FIPS', 


# ---------------------------------------------

'Numb_White', 'Numb_Black', 

# --------------------------------------------- County-Race

# (1) Part: Parity

"fluvax_Avg" , 
"fluvax_Disparity",
'fluvax_White', 'fluvax_Black', 'fluvax_Diff', 

'FluAvg', 
'FluDisparity',
'FluWhite', 'FluBlack', 'FluWhole',  'FluDiff', 

'FluAAAvg', 
'FluAADisparity',
'FluAAWhite', 'FluAABlack', 'FluAAWhole',  'FluAADiff', 


'Vax_Avg', 
'Vax_Disparity',
'Rate_White',  'Rate_Black', 'Rate_Diff',  

"HighSchool_Avg" , 
"HighSchool_Disparity",
'HighSchool_White', 'HighSchool_Black','HighSchool_Diff',

"Bachelor_Avg" , 
"Bachelor_Disparity",
'Bachelor_White',  'Bachelor_Black', 'Bachelor_Diff', 

"CI_Avg" , 
"CI_Disparity",
'CI_White', 'CI_Black', 'CI_Diff',

"CnoI_Avg" , 
"CnoI_Disparity",
'CnoI_White', 'CnoI_Black', 'CnoI_Diff',

"noC_Avg" , 
"noC_Disparity",
'noC_White', 'noC_Black', 'noC_Diff',

"Unemployment_Avg" , 
"Unemployment_Disparity",
'Unemployment_White', 'Unemployment_Black', 'Unemployment_Diff', 

# we have diff (only about 200 counties)

'Above75_WhiteRate', 'Above75_BlackRate', 'Above75_Disparity', 'Above75_Whole', 
'Above65_WhiteRate', 'Above65_BlackRate', 'Above65_Disparity', 'Above65_Whole', 
'Below19_WhiteRate', 'Below19_BlackRate', 'Below19_Disparity', 'Below19_Whole', 
'Below24_WhiteRate', 'Below24_BlackRate', 'Below24_Disparity', 'Below24_Whole', 
'Below29_WhiteRate', 'Below29_BlackRate', 'Below29_Disparity', 'Below29_Whole', 
'Below39_WhiteRate', 'Below39_BlackRate', 'Below39_Disparity', 'Below39_Whole',


# (2) Part: Diff  
"MeanIncome_Disparity",
"MeanIncome_DisparityB",
'MeanIncome_Diff', 
'MeanIncome_White', 'MeanIncome_Black', 

"MedianIncome_Disparity",
"MedianIncome_DisparityB",
'MedianIncome_Diff', 
'MedianIncome_White', 'MedianIncome_Black', 


# --------------------------------------------- County

'AREA_SQMI', 'DENSITY', 'urban',
'Total_Whole', 'Total_White', 'Total_Black',

'MeanIncome','MedianIncome', 
'EP_POV', 'ADIMean', 'ADIStd', 'SDI',
'Unemployment_Whole',



'HighSchool_Whole','Bachelor_Whole', 

'CI_Whole', 'CnoI_Whole','noC_Whole',

'Num_providerb', 'Num_providerc', 

'fixed_d', 'fixed_u', 'fixed_lat', 

'mobile_d', 'mobile_u', 'mobile_lat', 



'TCI', 'AvgTrafficVolume', 'EP_NOVEH', 

'FQHC', 'FacDensity10K', 'HOPD', 'PHMCY', 'RUHC', 'Rate_poorhealth',

'fluvax', 'undervaccination',

'barriers', 'resource_constrained', 'inaccessibility', 'irregular_behavior', 'CVAC', 


'cases', 'deaths', 'Incident_rate', 'mortality', 


'winner', 'votes_R', 'votes_D', 'votes_3party', 'votes_total', 'republican', 'republican_rate', 


'Segregation', 


'EP_DISABL', 'EP_MINRTY', 'EP_LIMENG', 


'RPL_THEME1',  'RPL_THEME2', 'RPL_THEME3', 'RPL_THEME4', 'RPL_THEMES', 

'injury_deaths', 'Rate_viocrime',

'racial_bias', 'racial_explicit_diff', 'racial_n_bias_obs', 'racial_n_explicit_obs', 'racial_weighted_bias', 'racial_weighted_explicit_diff', 
'sex_bias', 'sex_explicit', 'sex_n_bias_obs', 'sex_n_explicit_obs', 'sex_weighted_bias', 'sex_weighted_explicit',


]

T2 = T[cols]

# %%
T2
# Out:
#            State     County               AreaName   FIPS     Numb_White  \
# 0     California    Alameda    Alameda, California  06001  186256.131102
# 1     California     Amador     Amador, California  06005   10295.982504
# 2     California      Butte      Butte, California  06007   38755.387296
# 3     California  Calaveras  Calaveras, California  06009    8185.189474
# 4     California     Colusa     Colusa, California  06011    1767.066692
# ...          ...        ...                    ...    ...            ...
# 1270      Oregon   Columbia       Columbia, Oregon  41009    8522.000000
# 1271      Oregon    Clatsop        Clatsop, Oregon  41007    6313.000000
# 1272      Oregon  Clackamas      Clackamas, Oregon  41005   70058.000000
# 1273      Oregon     Benton         Benton, Oregon  41003   22067.000000
# 1274      Oregon      Baker          Baker, Oregon  41001    5669.000000
#
#         Numb_Black  fluvax_Avg  fluvax_Disparity  fluvax_White  fluvax_Black  \
# ...

# %%
T2[['FluDiff', 'FluDisparity']].describe()
# Out:
#            FluDiff  FluDisparity
# count  1029.000000   1029.000000
# mean      0.146064      0.316666
# std       0.080987      0.192283
# min      -0.220000     -0.610102
# 25%       0.100000      0.221865
# 50%       0.150000      0.323771
# 75%       0.190000      0.401300
# max       0.510000      1.129676

# %%
# T2.describe().T.to_csv('VariableDict.csv')

# %%
T2.to_csv('CountyVaccineApril07New.csv', index = False)
